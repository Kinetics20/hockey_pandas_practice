# %%
import pandas as pd

from set_paths import INTER

# %%
master = pd.read_pickle(INTER / 'master_2.pkl')
scoring = pd.read_pickle(INTER / 'master_score_2.pkl')

team_splits = pd.read_pickle(INTER / 'teams_team_splits_2.pkl')

# %%
scoring.head()
# Out:
#   firstName    lastName pos_x   playerID  year tmID    GP    G     A   Pts  \
# 0     Antti       Aalto     C  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0
# 1     Antti       Aalto     C  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0
# 2     Antti       Aalto     C  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0
# 3     Antti       Aalto     C  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0
# 4    Justin  Abdelkader     L  abdelju01  2007  DET   2.0  0.0   0.0   0.0
#
#      SOG pos_y
# 0    1.0   ANA
# 1   61.0   ANA
# 2  102.0   ANA
# 3   18.0   ANA
# 4    6.0   DET

# %%
mi = scoring.set_index(['playerID', 'year'])

# %%
mi.head()
# Out:
#                firstName    lastName pos_x tmID    GP    G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti       Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
#           1998     Antti       Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
#           1999     Antti       Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
#           2000     Antti       Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# abdelju01 2007    Justin  Abdelkader     L  DET   2.0  0.0   0.0   0.0    6.0
#
#                pos_y
# playerID  year
# aaltoan01 1997   ANA
#           1998   ANA
#           1999   ANA
#           2000   ANA
# abdelju01 2007   DET

# %%
mi.index
# Out:
# MultiIndex([('aaltoan01', 1997),
#             ('aaltoan01', 1998),
#             ('aaltoan01', 1999),
#             ('aaltoan01', 2000),
#             ('abdelju01', 2007),
#             ('abdelju01', 2008),
#             ('abdelju01', 2009),
#             ('abdelju01', 2010),
#             ('abdelju01', 2011),
#             ( 'abidra01', 2002),
#             ...
#             ('zyuzian01', 1999),
#             ('zyuzian01', 2000),
#             ('zyuzian01', 2001),
#             ('zyuzian01', 2001),
#             ('zyuzian01', 2002),
#             ('zyuzian01', 2002),
#             ('zyuzian01', 2003),
#             ('zyuzian01', 2005),
#             ('zyuzian01', 2006),
#             ('zyuzian01', 2007)],
#            names=['playerID', 'year'], length=28616)

# %%
type(mi)
# Out:
# pandas.core.frame.DataFrame

# %%
print(mi.index.name)
# Out:
# None

# %%
mi.index.names
# Out:
# FrozenList(['playerID', 'year'])

# %%
mi.index.name = 'playerID_year'

# %%
mi.index.levels
# Out:
# FrozenList([['aaltoan01', 'abdelju01', 'abidra01', 'abrahth01', 'actonke01', 'adamlu01', 'adamru01', 'adamsbr01', 'adamscr01', 'adamsgr01', 'adamsgr02', 'adamske01', 'aebisda01', 'afanadm01', 'afflebr01', 'afinoma01', 'agnewji01', 'aholape01', 'aitkebr01', 'aitkejo01', 'aivazmi01', 'alatami01', 'albelto01', 'alberan01', 'aldrike01', 'alexeni01', 'alfreda01', 'aliuak01', 'allenbo01', 'allenbr01', 'allench01', 'allenpe01', 'alleyst01', 'allisda01', 'allisja01', 'allisja02', 'allismi01', 'allisra01', 'almonco01', 'alzneka01', 'ambrope01', 'amontto01', 'andercr01', 'anderer01', 'andergl01', 'anderjo01', 'anderjo02', 'anderjo04', 'anderke01', 'andermi01', 'anderni01', 'anderpe01', 'anderpe02', 'anderpe03', 'anderru01', 'andersh01', 'andreda01', 'andrial01', 'andrugr01', 'angelme01', 'angelmi01', 'anholda01', 'anisiar01', 'antonmi01', 'antossh01', 'antroni01', 'archida01', 'archiji01', 'arkhide01', 'armstbi01', 'armstch01', 'armstco01', 'armstde01', 'armstri01', 'armstti01', 'arnasty01', '
# ...

# %%
mi.index.name
# Out:
# 'playerID_year'

# %%
len(mi.index.levels)
# Out:
# 2

# %%
mi.index.nlevels
# Out:
# 2

# %%
mi.index.levels[0]
# Out:
# Index(['aaltoan01', 'abdelju01', 'abidra01', 'abrahth01', 'actonke01',
#        'adamlu01', 'adamru01', 'adamsbr01', 'adamscr01', 'adamsgr01',
#        ...
#        'zolniha01', 'zombori01', 'zubaran01', 'zubovil01', 'zubovse01',
#        'zubruda01', 'zuccama01', 'zuckeja01', 'zukemi01', 'zyuzian01'],
#       dtype='object', name='playerID', length=4627)

# %%
mi.index.levels[1]
# Out:
# Index([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011],
#       dtype='int64', name='year')

# %%
mi.groupby(level='year')['G'].max().head()
# Out:
# year
# 1980    68.0
# 1981    92.0
# 1982    71.0
# 1983    87.0
# 1984    73.0
# Name: G, dtype: float64

# %%
mi.groupby(level='year')['G'].idxmax().head()
# Out:
# year
# 1980    (bossymi01, 1980)
# 1981    (gretzwa01, 1981)
# 1982    (gretzwa01, 1982)
# 1983    (gretzwa01, 1983)
# 1984    (gretzwa01, 1984)
# Name: G, dtype: object

# %%
mi.loc[('gretzwa01', 1982)]
# Out:
#                firstName lastName pos_x tmID    GP     G      A    Pts    SOG  \
# playerID  year
# gretzwa01 1982     Wayne  Gretzky     C  EDM  80.0  71.0  125.0  196.0  348.0
#
#                pos_y
# playerID  year
# gretzwa01 1982   EDM

# %%
mi.columns
# Out:
# Index(['firstName', 'lastName', 'pos_x', 'tmID', 'GP', 'G', 'A', 'Pts', 'SOG',
#        'pos_y'],
#       dtype='object')

# %%
mi.loc[(slice(None), slice('1997', '2000')), :]
# Out:
#                firstName lastName pos_x tmID    GP    G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti    Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
#           1998     Antti    Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
#           1999     Antti    Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
#           2000     Antti    Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# adamsbr01 1999     Bryan    Adams     L  ATL   2.0  0.0   0.0   0.0    1.0
# ...                  ...      ...   ...  ...   ...  ...   ...   ...    ...
# zubruda01 2000   Dainius   Zubrus     R  WAS  12.0  1.0   1.0   2.0   13.0
# zyuzian01 1997    Andrei   Zyuzin     D  SJS  56.0  6.0   7.0  13.0   72.0
#           1998    Andrei   Zyuzin     D  SJS  25.0  3.0   1.0   4.0   44.0
#           1999    Andrei   Zyuzin     D  TBL  34.0  2.0   9.0  11.0   47.0
#           2000    Andrei   Zyuzin     D  TBL  64.0  4.0  16.0  20.0   92.0
#
#                pos_y
# playerID  year
# ...

# %%
mi.loc[(slice(None)), (slice(None))]
# Out:
#                firstName    lastName pos_x tmID    GP    G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti       Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
#           1998     Antti       Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
#           1999     Antti       Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
#           2000     Antti       Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# abdelju01 2007    Justin  Abdelkader     L  DET   2.0  0.0   0.0   0.0    6.0
# ...                  ...         ...   ...  ...   ...  ...   ...   ...    ...
# zyuzian01 2002    Andrei      Zyuzin     D  MIN  66.0  4.0  12.0  16.0  113.0
#           2003    Andrei      Zyuzin     D  MIN  65.0  8.0  13.0  21.0  104.0
#           2005    Andrei      Zyuzin     D  MIN  57.0  7.0  11.0  18.0   80.0
#           2006    Andrei      Zyuzin     D  CAL  49.0  1.0   5.0   6.0   36.0
#           2007    Andrei      Zyuzin     D  CHI  32.0  2.0   3.0   5.0   34.0
#
# ...

# %%
idx = pd.IndexSlice
mi.loc[idx[:, 1997:2000], :]
# Out:
#                firstName lastName pos_x tmID    GP    G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti    Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
#           1998     Antti    Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
#           1999     Antti    Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
#           2000     Antti    Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# adamsbr01 1999     Bryan    Adams     L  ATL   2.0  0.0   0.0   0.0    1.0
# ...                  ...      ...   ...  ...   ...  ...   ...   ...    ...
# zubruda01 2000   Dainius   Zubrus     R  WAS  12.0  1.0   1.0   2.0   13.0
# zyuzian01 1997    Andrei   Zyuzin     D  SJS  56.0  6.0   7.0  13.0   72.0
#           1998    Andrei   Zyuzin     D  SJS  25.0  3.0   1.0   4.0   44.0
#           1999    Andrei   Zyuzin     D  TBL  34.0  2.0   9.0  11.0   47.0
#           2000    Andrei   Zyuzin     D  TBL  64.0  4.0  16.0  20.0   92.0
#
#                pos_y
# playerID  year
# ...

# %%
mi.loc[idx['aaltoan01': 'adamsgr02', 1997:2000], :]
# Out:
#                firstName lastName pos_x tmID    GP     G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti    Aalto     C  ANA   3.0   0.0   0.0   0.0    1.0
#           1998     Antti    Aalto     C  ANA  73.0   3.0   5.0   8.0   61.0
#           1999     Antti    Aalto     C  ANA  63.0   7.0  11.0  18.0  102.0
#           2000     Antti    Aalto     C  ANA  12.0   1.0   1.0   2.0   18.0
# adamsbr01 1999     Bryan    Adams     L  ATL   2.0   0.0   0.0   0.0    1.0
#           2000     Bryan    Adams     L  ATL   9.0   0.0   1.0   1.0    3.0
# adamscr01 2000     Craig    Adams     R  CAR  44.0   1.0   0.0   1.0   15.0
# adamsgr02 1997      Greg    Adams     L  DAL  49.0  14.0  18.0  32.0   75.0
#           1998      Greg    Adams     L  PHO  75.0  19.0  24.0  43.0  176.0
#           1999      Greg    Adams     L  PHO  69.0  19.0  27.0  46.0  129.0
#           2000      Greg    Adams     L  FLO  60.0  11.0  12.0  23.0   66.0
#
#                pos_y
# playerID  year
# ...

# %%
mi.loc[idx['aaltoan01': 'adamsgr02'], :]
# Out:
#                firstName    lastName pos_x tmID    GP     G     A   Pts  \
# playerID  year
# aaltoan01 1997     Antti       Aalto     C  ANA   3.0   0.0   0.0   0.0
#           1998     Antti       Aalto     C  ANA  73.0   3.0   5.0   8.0
#           1999     Antti       Aalto     C  ANA  63.0   7.0  11.0  18.0
#           2000     Antti       Aalto     C  ANA  12.0   1.0   1.0   2.0
# abdelju01 2007    Justin  Abdelkader     L  DET   2.0   0.0   0.0   0.0
# ...                  ...         ...   ...  ...   ...   ...   ...   ...
# adamsgr02 1996      Greg       Adams     L  DAL  50.0  21.0  15.0  36.0
#           1997      Greg       Adams     L  DAL  49.0  14.0  18.0  32.0
#           1998      Greg       Adams     L  PHO  75.0  19.0  24.0  43.0
#           1999      Greg       Adams     L  PHO  69.0  19.0  27.0  46.0
#           2000      Greg       Adams     L  FLO  60.0  11.0  12.0  23.0
#
#                   SOG pos_y
# playerID  year
# aaltoan01 1997    1.0   ANA
# ...

# %%
mi.loc[idx["aaltoan01":"adamsgr02":3, 1997:2000:2], :]
# Out:
#                firstName lastName pos_x tmID    GP    G     A   Pts    SOG  \
# playerID  year
# aaltoan01 1997     Antti    Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
#           1999     Antti    Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
#
#                pos_y
# playerID  year
# aaltoan01 1997   ANA
#           1999   ANA

# %%
swapped = mi.swaplevel()
swapped.head()
# Out:
#                firstName    lastName pos_x tmID    GP    G     A   Pts    SOG  \
# year playerID
# 1997 aaltoan01     Antti       Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
# 1998 aaltoan01     Antti       Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
# 1999 aaltoan01     Antti       Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
# 2000 aaltoan01     Antti       Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# 2007 abdelju01    Justin  Abdelkader     L  DET   2.0  0.0   0.0   0.0    6.0
#
#                pos_y
# year playerID
# 1997 aaltoan01   ANA
# 1998 aaltoan01   ANA
# 1999 aaltoan01   ANA
# 2000 aaltoan01   ANA
# 2007 abdelju01   DET

# %%
swapped = mi.swaplevel()
swapped.head()
# Out:
#                firstName    lastName pos_x tmID    GP    G     A   Pts    SOG  \
# year playerID
# 1997 aaltoan01     Antti       Aalto     C  ANA   3.0  0.0   0.0   0.0    1.0
# 1998 aaltoan01     Antti       Aalto     C  ANA  73.0  3.0   5.0   8.0   61.0
# 1999 aaltoan01     Antti       Aalto     C  ANA  63.0  7.0  11.0  18.0  102.0
# 2000 aaltoan01     Antti       Aalto     C  ANA  12.0  1.0   1.0   2.0   18.0
# 2007 abdelju01    Justin  Abdelkader     L  DET   2.0  0.0   0.0   0.0    6.0
#
#                pos_y
# year playerID
# 1997 aaltoan01   ANA
# 1998 aaltoan01   ANA
# 1999 aaltoan01   ANA
# 2000 aaltoan01   ANA
# 2007 abdelju01   DET

# %%
team_splits.head()
# Out:
#    year tmID  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  ...   GA  \
# 0  1980  BOS   NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN  ...  272
# 1  1980  BUF   NaN   NaN   NaN    NaN   5.0   2.0   2.0    NaN  ...  250
# 2  1980  CAL   NaN   NaN   NaN    NaN   5.0   4.0   2.0    NaN  ...  298
# 3  1980  CHI   NaN   NaN   NaN    NaN   6.0   4.0   2.0    NaN  ...  315
# 4  1980  COR   NaN   NaN   NaN    NaN   4.0   4.0   2.0    NaN  ...  344
#
#                   name     PIM  BenchMinor   PPG    PPC   SHA   PKG    PKC  \
# 0        Boston Bruins  1836.0        26.0  87.0  342.0   8.0  82.0  358.0
# 1       Buffalo Sabres  1194.0        22.0  73.0  310.0  10.0  44.0  268.0
# 2       Calgary Flames  1450.0        24.0  81.0  301.0  12.0  70.0  364.0
# 3  Chicago Black Hawks  1660.0        30.0  67.0  302.0   9.0  91.0  364.0
# 4     Colorado Rockies  1418.0        36.0  76.0  373.0   8.0  70.0  286.0
#
#     SHF
# 0  13.0
# 1   9.0
# 2   8.0
# 3   8.0
# 4   5.0
#
# ...

# %%
team_splits.drop(columns=['tmID'], inplace=True)

# %%
team_splits.set_index(['year', 'name'], inplace=True)

# %%
team_splits = team_splits.loc[:, 'SepW':'AprOL'].copy()

# %%
team_splits.head()
# Out:
#                           SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  \
# year name
# 1980 Boston Bruins         NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN
#      Buffalo Sabres        NaN   NaN   NaN    NaN   5.0   2.0   2.0    NaN
#      Calgary Flames        NaN   NaN   NaN    NaN   5.0   4.0   2.0    NaN
#      Chicago Black Hawks   NaN   NaN   NaN    NaN   6.0   4.0   2.0    NaN
#      Colorado Rockies      NaN   NaN   NaN    NaN   4.0   4.0   2.0    NaN
#
#                           NovW  NovL  ...  FebT  FebOL  MarW  MarL  MarT  \
# year name                             ...
# 1980 Boston Bruins         5.0   3.0  ...   2.0    NaN   8.0   4.0   3.0
#      Buffalo Sabres        8.0   4.0  ...   3.0    NaN   8.0   6.0   1.0
#      Calgary Flames        5.0   5.0  ...   1.0    NaN   6.0   6.0   2.0
#      Chicago Black Hawks   3.0   8.0  ...   4.0    NaN   4.0   5.0   4.0
#      Colorado Rockies      5.0   6.0  ...   2.0    NaN   4.0   9.0   1.0
#
# ...

# %%
months = team_splits.columns.map(lambda x: x[:3])
matrix = team_splits.columns.map(lambda x: x[3:])

# %%
months
# Out:
# Index(['Sep', 'Sep', 'Sep', 'Sep', 'Oct', 'Oct', 'Oct', 'Oct', 'Nov', 'Nov',
#        'Nov', 'Nov', 'Dec', 'Dec', 'Dec', 'Dec', 'Jan', 'Jan', 'Jan', 'Jan',
#        'Feb', 'Feb', 'Feb', 'Feb', 'Mar', 'Mar', 'Mar', 'Mar', 'Apr', 'Apr',
#        'Apr', 'Apr'],
#       dtype='object')

# %%
matrix
# Out:
# Index(['W', 'L', 'T', 'OL', 'W', 'L', 'T', 'OL', 'W', 'L', 'T', 'OL', 'W', 'L',
#        'T', 'OL', 'W', 'L', 'T', 'OL', 'W', 'L', 'T', 'OL', 'W', 'L', 'T',
#        'OL', 'W', 'L', 'T', 'OL'],
#       dtype='object')

# %%
multi_index = pd.MultiIndex.from_arrays([months, matrix])
multi_index
# Out:
# MultiIndex([('Sep',  'W'),
#             ('Sep',  'L'),
#             ('Sep',  'T'),
#             ('Sep', 'OL'),
#             ('Oct',  'W'),
#             ('Oct',  'L'),
#             ('Oct',  'T'),
#             ('Oct', 'OL'),
#             ('Nov',  'W'),
#             ('Nov',  'L'),
#             ('Nov',  'T'),
#             ('Nov', 'OL'),
#             ('Dec',  'W'),
#             ('Dec',  'L'),
#             ('Dec',  'T'),
#             ('Dec', 'OL'),
#             ('Jan',  'W'),
#             ('Jan',  'L'),
#             ('Jan',  'T'),
#             ('Jan', 'OL'),
#             ('Feb',  'W'),
#             ('Feb',  'L'),
#             ('Feb',  'T'),
#             ('Feb', 'OL'),
#             ('Mar',  'W'),
#             ('Mar',  'L'),
#             ('Mar',  'T'),
#             ('Mar', 'OL'),
#             ('Apr',  'W'),
#             ('Apr',  'L'),
#             ('Apr',  'T'),
#             ('Apr', 'OL')],
#            )

# %%
team_splits.columns = multi_index
team_splits.head()
# Out:
#                          Sep              Oct                Nov       ...  \
#                            W   L   T  OL    W    L    T  OL    W    L  ...
# year name                                                              ...
# 1980 Boston Bruins       NaN NaN NaN NaN  2.0  7.0  1.0 NaN  5.0  3.0  ...
#      Buffalo Sabres      NaN NaN NaN NaN  5.0  2.0  2.0 NaN  8.0  4.0  ...
#      Calgary Flames      NaN NaN NaN NaN  5.0  4.0  2.0 NaN  5.0  5.0  ...
#      Chicago Black Hawks NaN NaN NaN NaN  6.0  4.0  2.0 NaN  3.0  8.0  ...
#      Colorado Rockies    NaN NaN NaN NaN  4.0  4.0  2.0 NaN  5.0  6.0  ...
#
#                           Feb      Mar                Apr
#                             T  OL    W    L    T  OL    W    L    T  OL
# year name
# 1980 Boston Bruins        2.0 NaN  8.0  4.0  3.0 NaN  1.0  2.0  0.0 NaN
#      Buffalo Sabres       3.0 NaN  8.0  6.0  1.0 NaN  1.0  1.0  1.0 NaN
#      Calgary Flames       1.0 NaN  6.0  6.0  2.0 NaN  2.0  0.0  0.0 NaN
# ...

# %%
team_splits =  team_splits.stack(level=0, future_stack=True)

# %%
team_splits.head()
# Out:
#                           W    L    T  OL
# year name
# 1980 Boston Bruins Sep  NaN  NaN  NaN NaN
#                    Oct  2.0  7.0  1.0 NaN
#                    Nov  5.0  3.0  5.0 NaN
#                    Dec  6.0  6.0  1.0 NaN
#                    Jan  9.0  4.0  1.0 NaN

# %%
team_splits.index.nlevels
# Out:
# 3

# %%
team_splits = team_splits.swaplevel(1, 2)

# %%
team_splits.head(2)
# Out:
#                           W    L    T  OL
# year     name
# 1980 Sep Boston Bruins  NaN  NaN  NaN NaN
#      Oct Boston Bruins  2.0  7.0  1.0 NaN

# %%
team_splits.index.names
# Out:
# FrozenList(['year', None, 'name'])

# %%
team_splits.index.set_names('months', level=2, inplace=True)

# %%
team_splits.head()
# Out:
#                           W    L    T  OL
# year     months
# 1980 Sep Boston Bruins  NaN  NaN  NaN NaN
#      Oct Boston Bruins  2.0  7.0  1.0 NaN
#      Nov Boston Bruins  5.0  3.0  5.0 NaN
#      Dec Boston Bruins  6.0  6.0  1.0 NaN
#      Jan Boston Bruins  9.0  4.0  1.0 NaN

# %%
team_splits.groupby(level=['year', 'year']).sum().sum(axis=1)
# Out:
# year  year
# 1980  1980    1680.0
# 1981  1981    1680.0
# 1982  1982    1680.0
# 1983  1983    1680.0
# 1984  1984    1680.0
# 1985  1985    1680.0
# 1986  1986    1680.0
# 1987  1987    1680.0
# 1988  1988    1680.0
# 1989  1989    1680.0
# 1990  1990    1680.0
# 1991  1991    1760.0
# 1992  1992    2016.0
# 1993  1993    2184.0
# 1994  1994    1208.0
# 1995  1995    2132.0
# 1996  1996    2132.0
# 1997  1997    2132.0
# 1998  1998    2214.0
# 1999  1999    2296.0
# 2000  2000    2460.0
# 2001  2001    2460.0
# 2002  2002    2460.0
# 2003  2003    2460.0
# 2005  2005    2460.0
# 2006  2006    2460.0
# 2007  2007    2460.0
# 2008  2008    2460.0
# 2009  2009    2460.0
# 2010  2010    2460.0
# 2011  2011    2460.0
# dtype: float64

# %%
team_splits.index.names
# Out:
# FrozenList(['year', None, 'months'])

# %%
team_splits.unstack(level=['year', 'months']).head()
# Out:
#                    W                                                    \
# year            1980
# months Boston Bruins Buffalo Sabres Calgary Flames Chicago Black Hawks
# Sep              NaN            NaN            NaN                 NaN
# Oct              2.0            5.0            5.0                 6.0
# Nov              5.0            8.0            5.0                 3.0
# Dec              6.0            5.0            6.0                 3.0
# Jan              9.0            6.0            6.0                 9.0
#
#                                                                             \
# year
# months Colorado Rockies Detroit Red Wings Edmonton Oilers Hartford Whalers
# Sep                 NaN               NaN             NaN              NaN
# Oct                 4.0               2.0             2.0              5.0
# Nov                 5.0               1.0             4.0              3.0
# ...

# %%
team_splits.to_pickle(INTER / 'teams_splits_multi_index_2.pkl')

# %%
mi.to_pickle(INTER / 'scoring_multi_index_2.pkl')
